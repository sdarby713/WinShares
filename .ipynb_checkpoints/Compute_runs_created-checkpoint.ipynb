# %%
import pandas as pd

# %%
park_factor_df = pd.read_csv("park_factor_stats.csv")
display(park_factor_df)
# Out:
#      year     team_id        team  runs at home for  hr at home for  \
# 0    2002   team-10-3     Anaheim               404              71
# 1    2003   team-10-3     Anaheim               352              68
# 2    2004   team-10-3     Anaheim               391              77
# 3    2005   team-10-3     Anaheim               361              71
# 4    2006   team-10-3     Anaheim               366              69
# 5    2007   team-10-3     Anaheim               460              61
# 6    2008   team-10-3     Anaheim               383              72
# 7    2009   team-10-3     Anaheim               444              90
# 8    2010   team-10-3     Anaheim               319              69
# 9    2011   team-10-3     Anaheim               305              62
# 10   2012   team-10-3     Anaheim               348              82
# 11   2013   team-10-3     Anaheim               352              77
# 12   2014   team-10-3     Anaheim               362              73
# ...

# %%
# since we built this dataframe file, we know that all data is present.  any field could be counted
df_length = park_factor_df.year.count()
display(park_factor_df.iloc[3,6])
# Out:
# 76

# %%
# for i in range(2,df_length)
for i in range(2,2):    # for testing
    curr_park = park_factor_df.iloc[i, 12]
    tot_weight = 4
    tot_r_home  = (park_factor_df.iloc[i, 4] + park_factor_df.iloc[i, 8])*4
    tot_r_road  = (park_factor_df.iloc[i, 6] + park_factor_df.iloc[i, 10])*4
    tot_hr_home = (park_factor_df.iloc[i, 5] + park_factor_df.iloc[i, 9])*4
    tot_hr_road = (park_factor_df.iloc[i, 7] + park_factor_df.iloc[i, 11])*4
    
    j = i - 2
    if (park_factor_df.iloc[j, 12] == curr_park):
        tot_weight += 1
        tot_r_home  += (park_factor_df.iloc[j, 4] + park_factor_df.iloc[j, 8])
        tot_r_road  += (park_factor_df.iloc[j, 6] + park_factor_df.iloc[j, 10])
        tot_hr_home += (park_factor_df.iloc[j, 5] + park_factor_df.iloc[j, 9])
        tot_hr_road += (park_factor_df.iloc[j, 7] + park_factor_df.iloc[j, 11])
        
    j = i - 1
    if (park_factor_df.iloc[j, 12] == curr_park):
        tot_weight += 1
        tot_r_home  += (park_factor_df.iloc[j, 4] + park_factor_df.iloc[j, 8])
        tot_r_road  += (park_factor_df.iloc[j, 6] + park_factor_df.iloc[j, 10])
        tot_hr_home += (park_factor_df.iloc[j, 5] + park_factor_df.iloc[j, 9])
        tot_hr_road += (park_factor_df.iloc[j, 7] + park_factor_df.iloc[j, 11])
        
    j = i + 1
    if (j <= df_length):    # don't go past end of data
        if (park_factor_df.iloc[j, 12] == curr_park):
            tot_weight += 1
            tot_r_home  += (park_factor_df.iloc[j, 4] + park_factor_df.iloc[j, 8])
            tot_r_road  += (park_factor_df.iloc[j, 6] + park_factor_df.iloc[j, 10])
            tot_hr_home += (park_factor_df.iloc[j, 5] + park_factor_df.iloc[j, 9])
            tot_hr_road += (park_factor_df.iloc[j, 7] + park_factor_df.iloc[j, 11])
            
    j = i + 2
    if (j <= df_length):    # don't go past end of data
        if (park_factor_df.iloc[j, 12] == curr_park):
            tot_weight += 1
            tot_r_home  += (park_factor_df.iloc[j, 4] + park_factor_df.iloc[j, 8])
            tot_r_road  += (park_factor_df.iloc[j, 6] + park_factor_df.iloc[j, 10])
            tot_hr_home += (park_factor_df.iloc[j, 5] + park_factor_df.iloc[j, 9])
            tot_hr_road += (park_factor_df.iloc[j, 7] + park_factor_df.iloc[j, 11])
            
    PRF  = (tot_r_home  / tot_weight) / (tot_r_road  / tot_weight)
    PHRF = (tot_hr_home / tot_weight) / (tot_hr_road / tot_weight)
# Out:
#   File "<ipython-input-12-91baf78446a2>", line 11
#     if (park_factor_df.iloc[j, 12] == curr_park)
#                                                 ^
# SyntaxError: invalid syntax
